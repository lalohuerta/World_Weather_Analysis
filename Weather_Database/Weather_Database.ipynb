# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import requests
import time 

# Import the API key
from config import weather_api_key 

# Use the citipy module to degtermine city based on latitude and longitud 
from citipy import citipy

# Import the datetime module from the datetime library 
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
#for coordinate in coordinates: 
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          #citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list holding the cities 
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 749

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0b10d7ecfaa59b138e52388d7eb940ac

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descrption = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, 
                         "Current Description": city_weather_descrption})
                        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | la ronge
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | kruisfontein
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | dzemul
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | solnechnyy
# Processing Record 8 of Set 1 | dimataling
# Processing Record 9 of Set 1 | mounana
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 1 | bima
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | soyo
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | sabang
# Processing Record 24 of Set 1 | kavieng
# Processing Record 25 of Set 1 | kazachinskoye
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | guadalupe victoria
# Processing Record 34 of Set 1 | amboasary
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | damara
# Processing Record 38 of Set 1 | dongsheng
# Processing Record 39 of Set 1 | trelew
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | liverpool
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | ambon
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | anadyr
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | wazzan
# City not found. Skipping...
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | bocaranga
# City not found. Skipping...
# Processing Record 3 of Set 2 | narwar
# Processing Record 4 of Set 2 | concordia
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | itoman
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | haines junction
# Processing Record 10 of Set 2 | chicama
# Processing Record 11 of Set 2 | evensk
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | jimenez
# Processing Record 15 of Set 2 | esperance
# Processing Record 16 of Set 2 | alyangula
# Processing Record 17 of Set 2 | te anau
# Processing Record 18 of Set 2 | kabo
# Processing Record 19 of Set 2 | sfantu gheorghe
# Processing Record 20 of Set 2 | palmas
# Processing Record 21 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 2 | muisne
# Processing Record 23 of Set 2 | tukrah
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | zhireken
# Processing Record 26 of Set 2 | port arthur
# Processing Record 27 of Set 2 | shingu
# Processing Record 28 of Set 2 | banfora
# Processing Record 29 of Set 2 | tombouctou
# Processing Record 30 of Set 2 | pimentel
# Processing Record 31 of Set 2 | flinders
# Processing Record 32 of Set 2 | cherskiy
# Processing Record 33 of Set 2 | njombe
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | aswan
# Processing Record 36 of Set 2 | hofn
# Processing Record 37 of Set 2 | mandalgovi
# Processing Record 38 of Set 2 | praxedis guerrero
# Processing Record 39 of Set 2 | sola
# Processing Record 40 of Set 2 | lompoc
# Processing Record 41 of Set 2 | touros
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | biak
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | nhulunbuy
# Processing Record 47 of Set 2 | kerman
# Processing Record 48 of Set 2 | srednekolymsk
# Processing Record 49 of Set 2 | seryshevo
# Processing Record 50 of Set 2 | wang saphung
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | harper
# Processing Record 3 of Set 3 | inhambane
# Processing Record 4 of Set 3 | rocha
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | tornio
# Processing Record 10 of Set 3 | krasnokamensk
# Processing Record 11 of Set 3 | christchurch
# Processing Record 12 of Set 3 | pasni
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | tezu
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | minab
# Processing Record 18 of Set 3 | teahupoo
# Processing Record 19 of Set 3 | necochea
# Processing Record 20 of Set 3 | turukhansk
# Processing Record 21 of Set 3 | half moon bay
# Processing Record 22 of Set 3 | narsaq
# Processing Record 23 of Set 3 | hambantota
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | sharjah
# Processing Record 26 of Set 3 | bucerias
# Processing Record 27 of Set 3 | xuanhua
# Processing Record 28 of Set 3 | komsomolskiy
# Processing Record 29 of Set 3 | kaitangata
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | pacific grove
# Processing Record 32 of Set 3 | cabo san lucas
# Processing Record 33 of Set 3 | myaundzha
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | plettenberg bay
# Processing Record 36 of Set 3 | labelle
# Processing Record 37 of Set 3 | san patricio
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | santo antonio do ica
# Processing Record 40 of Set 3 | mahibadhoo
# Processing Record 41 of Set 3 | agadez
# Processing Record 42 of Set 3 | faya
# Processing Record 43 of Set 3 | dondo
# Processing Record 44 of Set 3 | nemuro
# Processing Record 45 of Set 3 | panjab
# Processing Record 46 of Set 3 | panorama
# Processing Record 47 of Set 3 | nchelenge
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | kenai
# Processing Record 50 of Set 3 | saint anthony
# Processing Record 1 of Set 4 | pitimbu
# Processing Record 2 of Set 4 | port hardy
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | amarante do maranhao
# Processing Record 8 of Set 4 | olenino
# Processing Record 9 of Set 4 | lircay
# Processing Record 10 of Set 4 | nome
# Processing Record 11 of Set 4 | flin flon
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | shelburne
# Processing Record 14 of Set 4 | lucea
# Processing Record 15 of Set 4 | batagay
# Processing Record 16 of Set 4 | markala
# Processing Record 17 of Set 4 | dingli
# Processing Record 18 of Set 4 | namibe
# Processing Record 19 of Set 4 | quatre cocos
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | kangaatsiaq
# Processing Record 22 of Set 4 | kapaa
# Processing Record 23 of Set 4 | maragogi
# Processing Record 24 of Set 4 | chuy
# Processing Record 25 of Set 4 | bowmore
# Processing Record 26 of Set 4 | abu samrah
# Processing Record 27 of Set 4 | ilulissat
# Processing Record 28 of Set 4 | ferme-neuve
# Processing Record 29 of Set 4 | hilton head island
# Processing Record 30 of Set 4 | saint-leu
# Processing Record 31 of Set 4 | tanggu
# Processing Record 32 of Set 4 | dikson
# Processing Record 33 of Set 4 | churapcha
# Processing Record 34 of Set 4 | florianopolis
# Processing Record 35 of Set 4 | kananga
# Processing Record 36 of Set 4 | vila velha
# Processing Record 37 of Set 4 | comodoro rivadavia
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | marsa matruh
# Processing Record 40 of Set 4 | derzhavinsk
# Processing Record 41 of Set 4 | muros
# Processing Record 42 of Set 4 | rio gallegos
# Processing Record 43 of Set 4 | barrow
# Processing Record 44 of Set 4 | vao
# Processing Record 45 of Set 4 | golaghat
# Processing Record 46 of Set 4 | santa maria
# Processing Record 47 of Set 4 | tromso
# Processing Record 48 of Set 4 | hithadhoo
# Processing Record 49 of Set 4 | emerald
# Processing Record 50 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 5 | codrington
# Processing Record 3 of Set 5 | sur
# Processing Record 4 of Set 5 | lisakovsk
# Processing Record 5 of Set 5 | napanee
# Processing Record 6 of Set 5 | homer
# Processing Record 7 of Set 5 | marawi
# Processing Record 8 of Set 5 | pringsewu
# Processing Record 9 of Set 5 | yellowknife
# Processing Record 10 of Set 5 | aiquile
# Processing Record 11 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 5 | nikolskoye
# Processing Record 13 of Set 5 | geraldton
# Processing Record 14 of Set 5 | zhigansk
# Processing Record 15 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 5 | yar-sale
# Processing Record 17 of Set 5 | mandera
# Processing Record 18 of Set 5 | okha
# Processing Record 19 of Set 5 | cartagena
# Processing Record 20 of Set 5 | ponta do sol
# Processing Record 21 of Set 5 | valkla
# Processing Record 22 of Set 5 | simao
# Processing Record 23 of Set 5 | lasa
# Processing Record 24 of Set 5 | sorland
# Processing Record 25 of Set 5 | honningsvag
# Processing Record 26 of Set 5 | naron
# Processing Record 27 of Set 5 | dillon
# Processing Record 28 of Set 5 | marsh harbour
# Processing Record 29 of Set 5 | werda
# Processing Record 30 of Set 5 | kerrobert
# Processing Record 31 of Set 5 | poum
# Processing Record 32 of Set 5 | ishigaki
# Processing Record 33 of Set 5 | chapleau
# Processing Record 34 of Set 5 | gostyn
# Processing Record 35 of Set 5 | nago
# Processing Record 36 of Set 5 | le port
# Processing Record 37 of Set 5 | alamosa
# Processing Record 38 of Set 5 | brigantine
# Processing Record 39 of Set 5 | abu dhabi
# Processing Record 40 of Set 5 | rio grande
# Processing Record 41 of Set 5 | isoka
# Processing Record 42 of Set 5 | nerchinskiy zavod
# Processing Record 43 of Set 5 | puerto del rosario
# Processing Record 44 of Set 5 | leningradskiy
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | colac
# Processing Record 47 of Set 5 | yulara
# Processing Record 48 of Set 5 | arcachon
# Processing Record 49 of Set 5 | gao
# Processing Record 50 of Set 5 | natal
# Processing Record 1 of Set 6 | ramsar
# Processing Record 2 of Set 6 | sungaipenuh
# Processing Record 3 of Set 6 | south valley
# Processing Record 4 of Set 6 | hobyo
# Processing Record 5 of Set 6 | talnakh
# Processing Record 6 of Set 6 | grand-lahou
# Processing Record 7 of Set 6 | luanda
# Processing Record 8 of Set 6 | boatlaname
# City not found. Skipping...
# Processing Record 9 of Set 6 | turbat
# Processing Record 10 of Set 6 | leatherhead
# Processing Record 11 of Set 6 | grindavik
# Processing Record 12 of Set 6 | constantine
# Processing Record 13 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 6 | coolum beach
# Processing Record 15 of Set 6 | kichera
# Processing Record 16 of Set 6 | hasaki
# Processing Record 17 of Set 6 | kiunga
# Processing Record 18 of Set 6 | severnoye
# Processing Record 19 of Set 6 | mwene-ditu
# Processing Record 20 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 6 | cervo
# Processing Record 22 of Set 6 | pangnirtung
# Processing Record 23 of Set 6 | cuencame
# Processing Record 24 of Set 6 | college
# Processing Record 25 of Set 6 | aleppo
# Processing Record 26 of Set 6 | manthani
# Processing Record 27 of Set 6 | ampanihy
# Processing Record 28 of Set 6 | nizwa
# Processing Record 29 of Set 6 | kavaratti
# Processing Record 30 of Set 6 | khorixas
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 6 | batagay-alyta
# Processing Record 34 of Set 6 | naze
# Processing Record 35 of Set 6 | ilinskiy
# Processing Record 36 of Set 6 | husavik
# Processing Record 37 of Set 6 | stornoway
# Processing Record 38 of Set 6 | avera
# Processing Record 39 of Set 6 | saldanha
# Processing Record 40 of Set 6 | parsabad
# Processing Record 41 of Set 6 | baglung
# Processing Record 42 of Set 6 | laguna
# Processing Record 43 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 6 | imbituba
# Processing Record 45 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 6 | methoni
# Processing Record 47 of Set 6 | nouakchott
# Processing Record 48 of Set 6 | harbin
# Processing Record 49 of Set 6 | tual
# Processing Record 50 of Set 6 | bianzhuang
# Processing Record 1 of Set 7 | aripuana
# City not found. Skipping...
# Processing Record 2 of Set 7 | tanout
# City not found. Skipping...
# Processing Record 3 of Set 7 | bereda
# City not found. Skipping...
# Processing Record 4 of Set 7 | lorengau
# City not found. Skipping...
# Processing Record 5 of Set 7 | aklavik
# City not found. Skipping...
# Processing Record 6 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record
of Set 9 | yialos
# City not found. Skipping...
# Processing Record 16 of Set 9 | bajil
# Processing Record 17 of Set 9 | meulaboh
# Processing Record 18 of Set 9 | fortuna
# Processing Record 19 of Set 9 | russell
# Processing Record 20 of Set 9 | cidreira
# Processing Record 21 of Set 9 | cap malheureux
# Processing Record 22 of Set 9 | port blair
# Processing Record 23 of Set 9 | la sarre
# Processing Record 24 of Set 9 | voznesenskoye
# Processing Record 25 of Set 9 | karasjok
# Processing Record 26 of Set 9 | yemtsa
# Processing Record 27 of Set 9 | oksfjord
# Processing Record 28 of Set 9 | arman
# Processing Record 29 of Set 9 | hokitika
# Processing Record 30 of Set 9 | tambovka
# Processing Record 31 of Set 9 | drumheller
# Processing Record 32 of Set 9 | gazni
# City not found. Skipping...
# Processing Record 33 of Set 9 | fort nelson
# Processing Record 34 of Set 9 | laguna de duero
# Processing Record 35 of Set 9 | blackwater
# Processing Record 36 of Set 9 | bequimao
# Processing Record 37 of Set 9 | okhotsk
# Processing Record 38 of Set 9 | tilichiki
# Processing Record 39 of Set 9 | svetlogorsk
# Processing Record 40 of Set 9 | hervey bay
# Processing Record 41 of Set 9 | nyurba
# Processing Record 42 of Set 9 | deputatskiy
# Processing Record 43 of Set 9 | milton keynes
# Processing Record 44 of Set 9 | vardo
# Processing Record 45 of Set 9 | port elizabeth
# Processing Record 46 of Set 9 | chake chake
# Processing Record 47 of Set 9 | myatlevo
# Processing Record 48 of Set 9 | shakiso
# Processing Record 49 of Set 9 | nanortalik
# Processing Record 50 of Set 9 | bahir dar
# Processing Record 1 of Set 10 | morlaix
# Processing Record 2 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 3 of Set 10 | greenville
# Processing Record 4 of Set 10 | vanimo
# Processing Record 5 of Set 10 | bijie
# Processing Record 6 of Set 10 | pontivy
# Processing Record 7 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 10 | la suiza
# Processing Record 9 of Set 10 | manado
# Processing Record 10 of Set 10 | kahului
# Processing Record 11 of Set 10 | grand gaube
# Processing Record 12 of Set 10 | tshikapa
# Processing Record 13 of Set 10 | ilovlya
# Processing Record 14 of Set 10 | snasa
# Processing Record 15 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 10 | campos novos
# Processing Record 17 of Set 10 | keuruu
# Processing Record 18 of Set 10 | yerbogachen
# Processing Record 19 of Set 10 | sinnamary
# Processing Record 20 of Set 10 | arona
# Processing Record 21 of Set 10 | tura
# Processing Record 22 of Set 10 | cosala
# Processing Record 23 of Set 10 | manokwari
# Processing Record 24 of Set 10 | ericeira
# Processing Record 25 of Set 10 | chaihe
# Processing Record 26 of Set 10 | musafirkhana
# Processing Record 27 of Set 10 | siguiri
# Processing Record 28 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 29 of Set 10 | kieta
# Processing Record 30 of Set 10 | aksu
# Processing Record 31 of Set 10 | lai
# Processing Record 32 of Set 10 | abbeville
# Processing Record 33 of Set 10 | leirvik
# Processing Record 34 of Set 10 | ixtapa
# Processing Record 35 of Set 10 | meiganga
# Processing Record 36 of Set 10 | rudsar
# Processing Record 37 of Set 10 | belmonte
# Processing Record 38 of Set 10 | hirara
# Processing Record 39 of Set 10 | mezen
# Processing Record 40 of Set 10 | kamenka
# Processing Record 41 of Set 10 | kuytun
# Processing Record 42 of Set 10 | phenix city
# Processing Record 43 of Set 10 | talara
# Processing Record 44 of Set 10 | huarmey
# Processing Record 45 of Set 10 | baruun-urt
# Processing Record 46 of Set 10 | alofi
# Processing Record 47 of Set 10 | sobolevo
# Processing Record 48 of Set 10 | tres lagoas
# Processing Record 49 of Set 10 | ponta delgada
# Processing Record 50 of Set 10 | bentiu
# Processing Record 1 of Set 11 | kapit
# Processing Record 2 of Set 11 | albury
# Processing Record 3 of Set 11 | klaksvik
# Processing Record 4 of Set 11 | chakulia
# Processing Record 5 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 11 | gazli
# Processing Record 7 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 11 | san javier
# Processing Record 9 of Set 11 | saint-pierre
# Processing Record 10 of Set 11 | sitio novo do tocantins
# Processing Record 11 of Set 11 | asau
# Processing Record 12 of Set 11 | cockburn town
# Processing Record 13 of Set 11 | lichinga
# Processing Record 14 of Set 11 | saiha
# Processing Record 15 of Set 11 | saint-louis
# Processing Record 16 of Set 11 | tecuala
# Processing Record 17 of Set 11 | diamantino
# Processing Record 18 of Set 11 | salmas
# Processing Record 19 of Set 11 | lufilufi
# Processing Record 20 of Set 11 | port lincoln
# Processing Record 21 of Set 11 | jumla
# Processing Record 22 of Set 11 | gravdal
# Processing Record 23 of Set 11 | huai yot
# Processing Record 24 of Set 11 | kiomboi
# Processing Record 25 of Set 11 | isangel
# Processing Record 26 of Set 11 | cizre
# Processing Record 27 of Set 11 | sinjar
# Processing Record 28 of Set 11 | mecca
# Processing Record 29 of Set 11 | tsementnyy
# Processing Record 30 of Set 11 | almaznyy
# Processing Record 31 of Set 11 | andenes
# Processing Record 32 of Set 11 | pandan
# Processing Record 33 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 11 | beringovskiy
# Processing Record 35 of Set 11 | grants pass
# Processing Record 36 of Set 11 | santa vitoria do palmar
# Processing Record 37 of Set 11 | baykit
# Processing Record 38 of Set 11 | santa cruz
# Processing Record 39 of Set 11 | angra
# City not found. Skipping...
# Processing Record 40 of Set 11 | masvingo
# Processing Record 41 of Set 11 | namikupa
# Processing Record 42 of Set 11 | minbu
# Processing Record 43 of Set 11 | bilma
# Processing Record 44 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 45 of Set 11 | santona
# Processing Record 46 of Set 11 | ugoofaaru
# Processing Record 47 of Set 11 | diadema
# Processing Record 48 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 11 | hamilton
# Processing Record 50 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 12 | amahai
# Processing Record 2 of Set 12 | fairview
# Processing Record 3 of Set 12 | zhuhai
# Processing Record 4 of Set 12 | nenita
# Processing Record 5 of Set 12 | caravelas
# Processing Record 6 of Set 12 | lubumbashi
# Processing Record 7 of Set 12 | porto novo
# Processing Record 8 of Set 12 | pinawa
# Processing Record 9 of Set 12 | antanifotsy
# Processing Record 10 of Set 12 | mahanoro
# Processing Record 11 of Set 12 | havelock
# Processing Record 12 of Set 12 | kirakira
# Processing Record 13 of Set 12 | coquimbo
# Processing Record 14 of Set 12 | marshall
# Processing Record 15 of Set 12 | olinda
# Processing Record 16 of Set 12 | whitehorse
# Processing Record 17 of Set 12 | roald
# Processing Record 18 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 12 | menongue
# Processing Record 20 of Set 12 | mazagao
# Processing Record 21 of Set 12 | szigetcsep
# Processing Record 22 of Set 12 | sisimiut
# Processing Record 23 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 12 | visnes
# Processing Record 25 of Set 12 | boden
# Processing Record 26 of Set 12 | paamiut
# Processing Record 27 of Set 12 | umba
# Processing Record 28 of Set 12 | danane
# Processing Record 29 of Set 12 | chowchilla
# Processing Record 30 of Set 12 | les cayes
# Processing Record 31 of Set 12 | chumikan
# Processing Record 32 of Set 12 | magog
# Processing Record 33 of Set 12 | desnogorsk
# Processing Record 34 of Set 12 | la libertad
# Processing Record 35 of Set 12 | koumac
# Processing Record 36 of Set 12 | knysna
# Processing Record 37 of Set 12 | ocean springs
# Processing Record 38 of Set 12 | trenggalek
# Processing Record 39 of Set 12 | alvdal
# Processing Record 40 of Set 12 | port hedland
# Processing Record 41 of Set 12 | altay
# Processing Record 42 of Set 12 | loubomo
# Processing Record 43 of Set 12 | mangan
# Processing Record 44 of Set 12 | san juan
# Processing Record 45 of Set 12 | pestravka
# Processing Record 46 of Set 12 | sept-iles
# Processing Record 47 of Set 12 | mercedes
# Processing Record 48 of Set 12 | finschhafen
# Processing Record 49 of Set 12 | luwuk
# Processing Record 50 of Set 12 | sibiti
# Processing Record 1 of Set 13 | senneterre
# Processing Record 2 of Set 13 | the pas
# Processing Record 3 of Set 13 | kathmandu
# Processing Record 4 of Set 13 | moa
# Processing Record 5 of Set 13 | bulawayo
# Processing Record 6 of Set 13 | gospic
# Processing Record 7 of Set 13 | kloulklubed
# Processing Record 8 of Set 13 | podbrdo
# Processing Record 9 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 13 | sungairaya
# Processing Record 11 of Set 13 | palmer
# Processing Record 12 of Set 13 | guabito
# Processing Record 13 of Set 13 | blagoyevo
# Processing Record 14 of Set 13 | vizinga
# Processing Record 15 of Set 13 | balikpapan
# Processing Record 16 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 18 of Set 13 | jinxi
# Processing Record 19 of Set 13 | bardiyah
# Processing Record 20 of Set 13 | diban
# Processing Record 21 of Set 13 | portland
# Processing Record 22 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 13 | humaita
# Processing Record 24 of Set 13 | san cristobal
# Processing Record 25 of Set 13 | marienburg
# Processing Record 26 of Set 13 | pangoa
# Processing Record 27 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 28 of Set 13 | bridlington
# Processing Record 29 of Set 13 | ambulu
# Processing Record 30 of Set 13 | lucapa
# Processing Record 31 of Set 13 | banda aceh
# Processing Record 32 of Set 13 | jiazi
# Processing Record 33 of Set 13 | seymchan
# Processing Record 34 of Set 13 | nicoya
# Processing Record 35 of Set 13 | northam
# Processing Record 36 of Set 13 | kharan
# Processing Record 37 of Set 13 | launceston
# Processing Record 38 of Set 13 | samarai
# Processing Record 39 of Set 13 | atar
# Processing Record 40 of Set 13 | trairi
# Processing Record 41 of Set 13 | ati
# Processing Record 42 of Set 13 | les escoumins
# Processing Record 43 of Set 13 | vila franca do campo
# Processing Record 44 of Set 13 | tallahassee
# Processing Record 45 of Set 13 | minuri
# Processing Record 46 of Set 13 | rosetta
# Processing Record 47 of Set 13 | colares
# Processing Record 48 of Set 13 | lillooet
# Processing Record 49 of Set 13 | milkovo
# Processing Record 50 of Set 13 | porec
# Processing Record 1 of Set 14 | paungde
# Processing Record 2 of Set 14 | barra do garcas
# Processing Record 3 of Set 14 | ballina
# Processing Record 4 of Set 14 | tutoia
# Processing Record 5 of Set 14 | farafangana
# Processing Record 6 of Set 14 | amapa
# Processing Record 7 of Set 14 | cururupu
# Processing Record 8 of Set 14 | penzance
# Processing Record 9 of Set 14 | chernyshevskiy
# Processing Record 10 of Set 14 | dwarka
# Processing Record 11 of Set 14 | liepaja
# Processing Record 12 of Set 14 | kuybysheve
# Processing Record 13 of Set 14 | san ignacio
# Processing Record 14 of Set 14 | jacareacanga
# Processing Record 15 of Set 14 | ouagadougou
# Processing Record 16 of Set 14 | komsomolets
# Processing Record 17 of Set 14 | ahipara
# Processing Record 18 of Set 14 | dawson creek
# Processing Record 19 of Set 14 | bairiki
# Processing Record 20 of Set 14 | horsham
# Processing Record 21 of Set 14 | pundaguitan
# Processing Record 22 of Set 14 | coihaique
# Processing Record 23 of Set 14 | pilani
# Processing Record 24 of Set 14 | eyl
# Processing Record 25 of Set 14 | nacala
# Processing Record 26 of Set 14 | shimoda
# Processing Record 27 of Set 14 | buraydah
# Processing Record 28 of Set 14 | pervomayskoye
# Processing Record 29 of Set 14 | matane
# Processing Record 30 of Set 14 | prince rupert
# Processing Record 31 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 32 of Set 14 | long beach
# Processing Record 33 of Set 14 | zyryanka
# Processing Record 34 of Set 14 | piacabucu
# Processing Record 35 of Set 14 | skibbereen
# Processing Record 36 of Set 14 | umm kaddadah
# Processing Record 37 of Set 14 | kabanjahe
# Processing Record 38 of Set 14 | bakel
# Processing Record 39 of Set 14 | sosnovo-ozerskoye
# Processing Record 40 of Set 14 | waingapu
# Processing Record 41 of Set 14 | alice springs
# Processing Record 42 of Set 14 | nuuk
# Processing Record 43 of Set 14 | san joaquin
# Processing Record 44 of Set 14 | mankachar
# Processing Record 45 of Set 14 | grajewo
# Processing Record 46 of Set 14 | formosa
# Processing Record 47 of Set 14 | ust-nera
# Processing Record 48 of Set 14 | thinadhoo
# Processing Record 49 of Set 14 | mehamn
# Processing Record 50 of Set 14 | aykhal
# Processing Record 1 of Set 15 | pemangkat
# Processing Record 2 of Set 15 | miyako
# Processing Record 3 of Set 15 | ulladulla
# Processing Record 4 of Set 15 | puro
# Processing Record 5 of Set 15 | wasilla
# Processing Record 6 of Set 15 | bubaque
# Processing Record 7 of Set 15 | moerai
# Processing Record 8 of Set 15 | vestmannaeyjar
# Processing Record 9 of Set 15 | jardim
# Processing Record 10 of Set 15 | gazanjyk
# Processing Record 11 of Set 15 | ankazoabo
# Processing Record 12 of Set 15 | szentgotthard
# Processing Record 13 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 15 | aksay
# Processing Record 15 of Set 15 | taoudenni
# Processing Record 16 of Set 15 | visby
# Processing Record 17 of Set 15 | bathsheba
# Processing Record 18 of Set 15 | nanuque
# Processing Record 19 of Set 15 | starkville
# Processing Record 20 of Set 15 | yining
# Processing Record 21 of Set 15 | lahan
# Processing Record 22 of Set 15 | barcelos
# Processing Record 23 of Set 15 | gornopravdinsk
# Processing Record 24 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 15 | diffa
# Processing Record 26 of Set 15 | bastia
# Processing Record 27 of Set 15 | rapid valley
# Processing Record 28 of Set 15 | manacapuru
# Processing Record 29 of Set 15 | tanete
# Processing Record 30 of Set 15 | hornepayne
# Processing Record 31 of Set 15 | shagonar
# Processing Record 32 of Set 15 | jinchang
# Processing Record 33 of Set 15 | lempaala
# Processing Record 34 of Set 15 | sibolga
# Processing Record 35 of Set 15 | taunggyi
# Processing Record 36 of Set 15 | meadow lake
# Processing Record 37 of Set 15 | coahuayana
# Processing Record 38 of Set 15 | kiri buru
# Processing Record 39 of Set 15 | itarema
# Processing Record 40 of Set 15 | negombo
# Processing Record 41 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 42 of Set 15 | santa rosa
# Processing Record 43 of Set 15 | jalu
# Processing Record 44 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 15 | moose factory
# Processing Record 46 of Set 15 | bose
# Processing Record 47 of Set 15 | seoul
# Processing Record 48 of Set 15 | jinka
# Processing Record 49 of Set 15 | den helder
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      La Ronge  55.1001 -105.2842     64.40        47          13
# 1     Busselton -33.6500  115.3333     52.16        82          71
# 2  Kruisfontein -34.0033   24.7314     50.88        85          99
# 3      Khatanga  71.9667  102.5000     44.10        76         100
# 4        Dzemul  21.2000  -89.3000     75.06        93          91
# 5      Katsuura  35.1333  140.3000     82.54        83          75
# 6    Solnechnyy  50.7214  136.6319     57.96        92          85
# 7    Dimataling   7.5344  123.3738     79.68        82          73
# 8       Mounana  -1.4085   13.1586     77.94        57          71
# 9  Puerto Ayora  -0.7393  -90.3518     70.56        90          82
#
#    Wind Speed Country                 Date Current Description
# 0        6.49      CA  2022-08-10 23:12:46          few clouds
# 1        5.01      AU  2022-08-10 23:12:47       broken clouds
# 2        4.14      ZA  2022-08-10 23:12:47     overcast clouds
# 3       11.41      RU  2022-08-10 23:12:47     overcast clouds
# 4        6.78      MX  2022-08-10 23:12:48     overcast clouds
# 5       15.10      JP  2022-08-10 23:12:49       broken clouds
# 6        3.09      RU  2022-08-10 23:12:49     overcast clouds
# 7        3.62      PH  2022-08-10 23:12:50          light rain
# 8        4.18      GA  2022-08-10 23:12:50       broken clouds
# 9        7.00      EC  2022-08-10 23:11:12       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      La Ronge      CA  55.1001 -105.2842     64.40        47          13
# 1     Busselton      AU -33.6500  115.3333     52.16        82          71
# 2  Kruisfontein      ZA -34.0033   24.7314     50.88        85          99
# 3      Khatanga      RU  71.9667  102.5000     44.10        76         100
# 4        Dzemul      MX  21.2000  -89.3000     75.06        93          91
# 5      Katsuura      JP  35.1333  140.3000     82.54        83          75
# 6    Solnechnyy      RU  50.7214  136.6319     57.96        92          85
# 7    Dimataling      PH   7.5344  123.3738     79.68        82          73
# 8       Mounana      GA  -1.4085   13.1586     77.94        57          71
# 9  Puerto Ayora      EC  -0.7393  -90.3518     70.56        90          82
#
#    Wind Speed Current Description
# 0        6.49          few clouds
# 1        5.01       broken clouds
# 2        4.14     overcast clouds
# 3       11.41     overcast clouds
# 4        6.78     overcast clouds
# 5       15.10       broken clouds
# 6        3.09     overcast clouds
# 7        3.62          light rain
# 8        4.18       broken clouds
# 9        7.00       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/kg/63wcqn9x0bv4vnbpc1hl7_k00000gn/T/ipykernel_19629/1925920037.py in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
