# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import requests
import time 

# Import the API key
from config import weather_api_key 

# Use the citipy module to degtermine city based on latitude and longitud 
from citipy import citipy

# Import the datetime module from the datetime library 
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
#for coordinate in coordinates: 
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          #citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list holding the cities 
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 746

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0b10d7ecfaa59b138e52388d7eb940ac

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descrption = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, 
                         "Current Description": city_weather_descrption})
                        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | karwar
# Processing Record 2 of Set 1 | namibe
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 1 | acapulco
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | cihuatlan
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | zhongxing
# Processing Record 18 of Set 1 | biak
# Processing Record 19 of Set 1 | gat
# Processing Record 20 of Set 1 | port blair
# Processing Record 21 of Set 1 | ixtapa
# Processing Record 22 of Set 1 | westport
# Processing Record 23 of Set 1 | pringsewu
# Processing Record 24 of Set 1 | inuvik
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 1 | cam ranh
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | bathsheba
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | nouadhibou
# Processing Record 32 of Set 1 | turka
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | mindyak
# Processing Record 36 of Set 1 | sur
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | monrovia
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | geraldton
# Processing Record 42 of Set 1 | narsaq
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | llangefni
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 48 of Set 1 | vila franca do campo
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | peniche
# Processing Record 2 of Set 2 | tabug
# Processing Record 3 of Set 2 | tooele
# Processing Record 4 of Set 2 | vieques
# Processing Record 5 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 2 | north bend
# Processing Record 7 of Set 2 | makakilo city
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | margate
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | amasya
# Processing Record 12 of Set 2 | shahr-e babak
# Processing Record 13 of Set 2 | roma
# Processing Record 14 of Set 2 | deloraine
# Processing Record 15 of Set 2 | jardim
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | mombasa
# Processing Record 19 of Set 2 | millau
# Processing Record 20 of Set 2 | casper
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | aitape
# Processing Record 23 of Set 2 | gerash
# Processing Record 24 of Set 2 | morlaix
# Processing Record 25 of Set 2 | kalmunai
# Processing Record 26 of Set 2 | manavalakurichi
# Processing Record 27 of Set 2 | portland
# Processing Record 28 of Set 2 | muromtsevo
# Processing Record 29 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 2 | manga
# Processing Record 31 of Set 2 | urazovo
# Processing Record 32 of Set 2 | maykain
# City not found. Skipping...
# Processing Record 33 of Set 2 | mutoko
# Processing Record 34 of Set 2 | puerto escondido
# Processing Record 35 of Set 2 | taseyevo
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | husavik
# Processing Record 38 of Set 2 | owosso
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | kavieng
# Processing Record 42 of Set 2 | inhambane
# Processing Record 43 of Set 2 | port-gentil
# Processing Record 44 of Set 2 | zhigansk
# Processing Record 45 of Set 2 | kahului
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | souillac
# Processing Record 48 of Set 2 | porto santo
# Processing Record 49 of Set 2 | san quintin
# Processing Record 50 of Set 2 | arman
# Processing Record 1 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 2 of Set 3 | mount isa
# Processing Record 3 of Set 3 | olinda
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | najran
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | katsuura
# Processing Record 10 of Set 3 | aksarka
# Processing Record 11 of Set 3 | semporna
# Processing Record 12 of Set 3 | sioux lookout
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | vao
# Processing Record 16 of Set 3 | bar harbor
# Processing Record 17 of Set 3 | broken hill
# Processing Record 18 of Set 3 | yulara
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | kieta
# Processing Record 21 of Set 3 | brae
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | muros
# Processing Record 24 of Set 3 | vangaindrano
# Processing Record 25 of Set 3 | coahuayana
# Processing Record 26 of Set 3 | palu
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | dom pedrito
# Processing Record 29 of Set 3 | camacha
# Processing Record 30 of Set 3 | riyadh
# Processing Record 31 of Set 3 | nedryhayliv
# Processing Record 32 of Set 3 | ranong
# Processing Record 33 of Set 3 | cayenne
# Processing Record 34 of Set 3 | maldonado
# Processing Record 35 of Set 3 | sao joao da barra
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 3 | southbridge
# Processing Record 40 of Set 3 | madimba
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | fort nelson
# Processing Record 43 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 44 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 3 | codrington
# Processing Record 47 of Set 3 | kununurra
# Processing Record 48 of Set 3 | vitimskiy
# City not found. Skipping...
# Processing Record 49 of Set 3 | kruisfontein
# Processing Record 50 of Set 3 | faya
# Processing Record 1 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | granada
# Processing Record 4 of Set 4 | antofagasta
# Processing Record 5 of Set 4 | malanje
# Processing Record 6 of Set 4 | teguldet
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | balkanabat
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | kemin
# Processing Record 11 of Set 4 | college
# Processing Record 12 of Set 4 | ocara
# Processing Record 13 of Set 4 | jammalamadugu
# Processing Record 14 of Set 4 | touros
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | nizwa
# Processing Record 17 of Set 4 | hermanus
# Processing Record 18 of Set 4 | ampere
# Processing Record 19 of Set 4 | huangchuan
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | cape town
# Processing Record 22 of Set 4 | lincoln
# Processing Record 23 of Set 4 | hamilton
# Processing Record 24 of Set 4 | iralaya
# Processing Record 25 of Set 4 | nishihara
# Processing Record 26 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 4 | prado
# Processing Record 28 of Set 4 | salinopolis
# Processing Record 29 of Set 4 | taltal
# Processing Record 30 of Set 4 | concarneau
# Processing Record 31 of Set 4 | traverse city
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | yerbogachen
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | luderitz
# Processing Record 36 of Set 4 | ekibastuz
# Processing Record 37 of Set 4 | lashio
# Processing Record 38 of Set 4 | mehamn
# Processing Record 39 of Set 4 | wewak
# Processing Record 40 of Set 4 | vysokogornyy
# Processing Record 41 of Set 4 | ust-kuyga
# Processing Record 42 of Set 4 | takoradi
# Processing Record 43 of Set 4 | xingyi
# Processing Record 44 of Set 4 | hithadhoo
# Processing Record 45 of Set 4 | salekhard
# Processing Record 46 of Set 4 | melioratorov
# Processing Record 47 of Set 4 | barrow
# Processing Record 48 of Set 4 | filadelfia
# Processing Record 49 of Set 4 | nome
# Processing Record 50 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 5 | sabibah
# City not found. Skipping...
# Processing Record 2 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | iquitos
# Processing Record 5 of Set 5 | nurota
# Processing Record 6 of Set 5 | uyovu
# Processing Record 7 of Set 5 | tura
# Processing Record 8 of Set 5 | sao jose da coroa grande
# Processing Record 9 of Set 5 | olafsvik
# Processing Record 10 of Set 5 | banda aceh
# Processing Record 11 of Set 5 | bugiri
# Processing Record 12 of Set 5 | marystown
# Processing Record 13 of Set 5 | port hardy
# Processing Record 14 of Set 5 | karratha
# Processing Record 15 of Set 5 | haapiti
# Processing Record 16 of Set 5 | evensk
# Processing Record 17 of Set 5 | severo-kurilsk
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | lorengau
# Processing Record 20 of Set 5 | ramsar
# Processing Record 21 of Set 5 | pacific grove
# Processing Record 22 of Set 5 | leshan
# Processing Record 23 of Set 5 | manyana
# Processing Record 24 of Set 5 | buraydah
# Processing Record 25 of Set 5 | zholymbet
# Processing Record 26 of Set 5 | vardo
# Processing Record 27 of Set 5 | waipawa
# Processing Record 28 of Set 5 | san carlos de bariloche
# Processing Record 29 of Set 5 | nikolskoye
# Processing Record 30 of Set 5 | coquimbo
# Processing Record 31 of Set 5 | rosarito
# Processing Record 32 of Set 5 | altamira
# Processing Record 33 of Set 5 | cherskiy
# Processing Record 34 of Set 5 | salina
# Processing Record 35 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 5 | iqaluit
# Processing Record 37 of Set 5 | nanakuli
# Processing Record 38 of Set 5 | marawi
# Processing Record 39 of Set 5 | kang
# Processing Record 40 of Set 5 | vaasa
# Processing Record 41 of Set 5 | port elizabeth
# Processing Record 42 of Set 5 | pevek
# Processing Record 43 of Set 5 | waingapu
# Processing Record 44 of Set 5 | bonavista
# Processing Record 45 of Set 5 | sechura
# Processing Record 46 of Set 5 | beterou
# Processing Record 47 of Set 5 | honiara
# Processing Record 48 of Set 5 | gouyave
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | stara vyzhivka
# Processing Record 1 of Set 6 | praia da vitoria
# Processing Record 2 of Set 6 | lagoa
# Processing Record 3 of Set 6 | samana
# Processing Record 4 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 6 | la tuque
# Processing Record 7 of Set 6 | noumea
# Processing Record 8 of Set 6 | xining
# Processing Record 9 of Set 6 | machilipatnam
# Processing Record 10 of Set 6 | krasnoselkup
# Processing Record 11 of Set 6 | luebo
# Processing Record 12 of Set 6 | esperance
# Processing Record 13 of Set 6 | horodyshche
# Processing Record 14 of Set 6 | digha
# Processing Record 15 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 6 | ciro marina
# Processing Record 18 of Set 6 | wagar
# Processing Record 19 of Set 6 | tres arroyos
# Processing Record 20 of Set 6 | tasiilaq
# Processing Record 21 of Set 6 | inveraray
# City not found. Skipping...
# Processing Record 22 of Set 6 | birjand
# Processing Record 23 of Set 6 | marzuq
# Processing Record 24 of Set 6 | upernavik
# Processing Record 25 of Set 6 | castro
# Processing Record 26 of Set 6 | keetmanshoop
# Processing Record 27 of Set 6 | sorong
# Processing Record 28 of Set 6 | sete
# Processing Record 29 of Set 6 | sabang
# Processing Record 30 of Set 6 | griffith
# Processing Record 31 of Set 6 | goderich
# Processing Record 32 of Set 6 | saint-georges
# Processing Record 33 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 6 | meulaboh
# Processing Record 35 of Set 6 | te anau
# Processing Record 36 of Set 6 | ylivieska
# Processing Record 37 of Set 6 | yellowknife
# Processing Record 38 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 6 | seoul
# Processing Record 40 of Set 6 | tautira
# Processing Record 41 of Set 6 | basco
# Processing Record 42 of Set 6 | ust-omchug
# Processing Record 43 of Set 6 | acarau
# Processing Record 44 of Set 6 | palora
# Processing Record 45 of Set 6 | rurrenabaque
# Processing Record 46 of Set 6 | forbes
# Processing Record 47 of Set 6 | port augusta
# Processing Record 48 of Set 6 | kolobovo
# Processing Record 49 of Set 6 | ewa beach
# Processing Record 50 of Set 6 | erenhot
# Processing Record 1 of Set 7 | namangan
# Processing Record 2 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 3 of Set 7 | dingle
# Processing Record 4 of Set 7 | oranjemund
# Processing Record 5 of Set 7 | rundu
# Processing Record 6 of Set 7 | bambous virieux
# Processing Record 7 of Set 7 | maturin
# Processing Record 8 of Set 7 | novosheshminsk
# Processing Record 9 of Set 7 | neryungri
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | tirano
# Processing Record 12 of Set 7 | mahibadhoo
# Processing Record 13 of Set 7 | hofn
# Processing Record 14 of Set 7 | entre rios
# Processing Record 15 of Set 7 | ahipara
# Processing Record 16 of Set 7 | palmer
# Processing Record 17 of Set 7 | rivadavia
# Processing Record 18 of Set 7 | chara
# Processing Record 19 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 7 | santo antonio do amparo
# Processing Record 21 of Set 7 | boende
# Processing Record 22 of Set 7 | mitsamiouli
# Processing Record 23 of Set 7 | teacapan
# Processing Record 24 of Set 7 | norman wells
# Processing Record 25 of Set 7 | torbay
# Processing Record 26 of Set 7 | poum
# Processing Record 27 of Set 7 | jinchang
# Processing Record 28 of Set 7 | champerico
# Processing Record 29 of Set 7 | teya
# Processing Record 30 of Set 7 | las cruces
# Processing Record 31 of Set 7 | daru
# Processing Record 32 of Set 7 | cabras
# Processing Record 33 of Set 7 | saskylakh
# Processing Record 34 of Set 7 | roald
# Processing Record 35 of Set 7 | constitucion
# Processing Record 36 of Set 7 | barroso
# Processing Record 37 of Set 7 | sile
# Processing Record 38 of Set 7 | hami
# Processing Record 39 of Set 7 | kopong
# Processing Record 40 of Set 7 | buncrana
# Processing Record 41 of Set 7 | kralendijk
# Processing Record 42 of Set 7 | katherine
# Processing Record 43 of Set 7 | fairbanks
# Processing Record 44 of Set 7 | slantsy
# Processing Record 45 of Set 7 | ponta do sol
# Processing Record 46 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 47 of Set 7 | rangpur
# Processing Record 48 of Set 7 | listvyagi
# Processing Record 49 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 2 of Set 8 | conceicao do araguaia
# Processing Record 3 of Set 8 | guilin
# Processing Record 4 of Set 8 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 5 of Set 8 | rahden
# Processing Record 6 of Set 8 | osakarovka
# Processing Record 7 of Set 8 | kichmengskiy gorodok
# Processing Record 8 of Set 8 | asfi
# Processing Record 9 of Set 8 | sydney
# Processing Record 10 of Set 8 | umm kaddadah
# Processing Record 11 of Set 8 | hasaki
# Processing Record 12 of Set 8 | okhotsk
# Processing Record 13 of Set 8 | bujaru
# Processing Record 14 of Set 8 | pangnirtung
# Processing Record 15 of Set 8 | bac giang
# Processing Record 16 of Set 8 | wajir
# Processing Record 17 of Set 8 | nizhnevartovsk
# Processing Record 18 of Set 8 | ibra
# Processing Record 19 of Set 8 | sinnamary
# Processing Record 20 of Set 8 | aykhal
# Processing Record 21 of Set 8 | quatre cocos
# Processing Record 22 of Set 8 | bethel
# Processing Record 23 of Set 8 | caravelas
# Processing Record 24 of Set 8 | vanimo
# Processing Record 25 of Set 8 | sheltozero
# Processing Record 26 of Set 8 | tonj
# Processing Record 27 of Set 8 | auki
# Processing Record 28 of Set 8 | hit
# Processing Record 29 of Set 8 | pingyi
# Processing Record 30 of Set 8 | briancon
# Processing Record 31 of Set 8 | tecpan
# Processing Record 32 of Set 8 | eyrarbakki
# Processing Record 33 of Set 8 | ternate
# Processing Record 34 of Set 8 | sambava
# Processing Record 35 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 8 | astoria
# Processing Record 37 of Set 8 | san cristobal
# Processing Record 38 of Set 8 | kaffrine
# Processing Record 39 of Set 8 | port shepstone
# Processing Record 40 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 8 | matagami
# Processing Record 42 of Set 8 | panguna
# Processing Record 43 of Set 8 | ghatanji
# Processing Record 44 of Set 8 | dunedin
# Processing Record 45 of Set 8 | talnakh
# Processing Record 46 of Set 8 | mankera
# Processing Record 47 of Set 8 | san jeronimo
# Processing Record 48 of Set 8 | tazovskiy
# Processing Record 49 of Set 8 | sao gabriel da cachoeira
# Processing Record 50 of Set 8 | praia
# Processing Record 1 of Set 9 | port hedland
# Processing Record 2 of Set 9 | odzun
# Processing Record 3 of Set 9 | gloversville
# Processing Record 4 of Set 9 | owando
# Processing Record 5 of Set 9 | marsh harbour
# Processing Record 6 of Set 9 | richard toll
# City not found. Skipping...
# Processing Record 7 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 9 | makariv
# Processing Record 9 of Set 9 | santa eulalia
# Processing Record 10 of Set 9 | padang
# Processing Record 11 of Set 9 | alofi
# Processing Record 12 of Set 9 | banes
# Processing Record 13 of Set 9 | vilhena
# Processing Record 14 of Set 9 | bandipur
# Processing Record 15 of Set 9 | bontoc
# Processing Record 16 of Set 9 | the valley
# Processing Record 17 of Set 9 | sao filipe
# Processing Record 18 of Set 9 | nizhniy tsasuchey
# Processing Record 19 of Set 9 | vredendal
# Processing Record 20 of Set 9 | mandalgovi
# Processing Record 21 of Set 9 | nikel
# Processing Record 22 of Set 9 | huambo
# Processing Record 23 of Set 9 | harrisonburg
# Processing Record 24 of Set 9 | tanabe
# Processing Record 25 of Set 9 | pathein
# Processing Record 26 of Set 9 | lasa
# Processing Record 27 of Set 9 | abu dhabi
# Processing Record 28 of Set 9 | kigoma
# Processing Record 29 of Set 9 | mtwara
# Processing Record 30 of Set 9 | srikakulam
# Processing Record 31 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 9 | casale monferrato
# Processing Record 33 of Set 9 | suntar
# Processing Record 34 of Set 9 | labuhan
# Processing Record 35 of Set 9 | berlevag
# Processing Record 36 of Set 9 | rawson
# Processing Record 37 of Set 9 | paamiut
# Processing Record 38 of Set 9 | tonantins
# Processing Record 39 of Set 9 | ayan
# Processing Record 40 of Set 9 | qui nhon
# Processing Record 41 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 9 | srednekolymsk
# Processing Record 43 of Set 9 | port macquarie
# Processing Record 44 of Set 9 | halifax
# Processing Record 45 of Set 9 | morant bay
# Processing Record 46 of Set 9 | haines junction
# Processing Record 47 of Set 9 | teguise
# Processing Record 48 of Set 9 | longyearbyen
# Processing Record 49 of Set 9 | vila
# Processing Record 50 of Set 9 | saldanha
# Processing Record 1 of Set 10 | oda
# Processing Record 2 of Set 10 | yarkovo
# Processing Record 3 of Set 10 | mackay
# Processing Record 4 of Set 10 | huntsville
# Processing Record 5 of Set 10 | beisfjord
# Processing Record 6 of Set 10 | ridgecrest
# Processing Record 7 of Set 10 | vila velha
# Processing Record 8 of Set 10 | gokak
# Processing Record 9 of Set 10 | marigot
# Processing Record 10 of Set 10 | fortuna
# Processing Record 11 of Set 10 | axim
# Processing Record 12 of Set 10 | dikson
# Processing Record 13 of Set 10 | machesney park
# Processing Record 14 of Set 10 | kedrovyy
# Processing Record 15 of Set 10 | bubaque
# Processing Record 16 of Set 10 | zykovo
# Processing Record 17 of Set 10 | kingston
# Processing Record 18 of Set 10 | sembe
# Processing Record 19 of Set 10 | kuching
# Processing Record 20 of Set 10 | carutapera
# Processing Record 21 of Set 10 | tarabha
# Processing Record 22 of Set 10 | uige
# Processing Record 23 of Set 10 | goshen
# Processing Record 24 of Set 10 | lavrentiya
# Processing Record 25 of Set 10 | crowley
# Processing Record 26 of Set 10 | eyl
# Processing Record 27 of Set 10 | mogadishu
# Processing Record 28 of Set 10 | tilichiki
# Processing Record 29 of Set 10 | bambanglipuro
# Processing Record 30 of Set 10 | walvis bay
# Processing Record 31 of Set 10 | aldan
# Processing Record 32 of Set 10 | torrijos
# Processing Record 33 of Set 10 | havre-saint-pierre
# Processing Record 34 of Set 10 | sandpoint
# Processing Record 35 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 10 | salalah
# Processing Record 37 of Set 10 | batagay-alyta
# Processing Record 38 of Set 10 | trairi
# Processing Record 39 of Set 10 | pergamino
# Processing Record 40 of Set 10 | nanortalik
# Processing Record 41 of Set 10 | oktyabrskoye
# Processing Record 42 of Set 10 | puerto ayora
# Processing Record 43 of Set 10 | deputatskiy
# Processing Record 44 of Set 10 | richmond
# Processing Record 45 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 10 | ukiah
# Processing Record 47 of Set 10 | vestmannaeyjar
# Processing Record 48 of Set 10 | beyneu
# Processing Record 49 of Set 10 | balve
# Processing Record 50 of Set 10 | milos
# Processing Record 1 of Set 11 | blagoveshchenka
# Processing Record 2 of Set 11 | chandia
# Processing Record 3 of Set 11 | chitral
# Processing Record 4 of Set 11 | yar-sale
# Processing Record 5 of Set 11 | omboue
# Processing Record 6 of Set 11 | florence
# Processing Record 7 of Set 11 | nortelandia
# Processing Record 8 of Set 11 | eenhana
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | jining
# Processing Record 11 of Set 11 | carauari
# Processing Record 12 of Set 11 | smithers
# Processing Record 13 of Set 11 | abnub
# Processing Record 14 of Set 11 | klaksvik
# Processing Record 15 of Set 11 | tabou
# Processing Record 16 of Set 11 | harper
# Processing Record 17 of Set 11 | nelson bay
# Processing Record 18 of Set 11 | anadyr
# Processing Record 19 of Set 11 | prince rupert
# Processing Record 20 of Set 11 | santander
# Processing Record 21 of Set 11 | scarborough
# Processing Record 22 of Set 11 | alice springs
# Processing Record 23 of Set 11 | arlit
# Processing Record 24 of Set 11 | opalenica
# Processing Record 25 of Set 11 | ha tinh
# Processing Record 26 of Set 11 | cordoba
# Processing Record 27 of Set 11 | lompoc
# Processing Record 28 of Set 11 | jambi
# Processing Record 29 of Set 11 | lubango
# Processing Record 30 of Set 11 | macau
# Processing Record 31 of Set 11 | boo
# Processing Record 32 of Set 11 | san policarpo
# Processing Record 33 of Set 11 | havelock
# Processing Record 34 of Set 11 | los alamos
# Processing Record 35 of Set 11 | buin
# Processing Record 36 of Set 11 | arcachon
# Processing Record 37 of Set 11 | yemtsa
# Processing Record 38 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 11 | huarmey
# Processing Record 40 of Set 11 | sabzevar
# Processing Record 41 of Set 11 | whyalla
# Processing Record 42 of Set 11 | shaunavon
# Processing Record 43 of Set 11 | awbari
# Processing Record 44 of Set 11 | porto walter
# Processing Record 45 of Set 11 | pisco
# Processing Record 46 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 11 | lata
# Processing Record 48 of Set 11 | constantine
# Processing Record 49 of Set 11 | kavaratti
# Processing Record 50 of Set 11 | chapleau
# Processing Record 1 of Set 12 | naryan-mar
# Processing Record 2 of Set 12 | kachug
# Processing Record 3 of Set 12 | shakawe
# Processing Record 4 of Set 12 | norrtalje
# Processing Record 5 of Set 12 | tucupita
# Processing Record 6 of Set 12 | otorohanga
# Processing Record 7 of Set 12 | gambo
# Processing Record 8 of Set 12 | clyde river
# Processing Record 9 of Set 12 | verkhnyaya balkariya
# Processing Record 10 of Set 12 | portmore
# Processing Record 11 of Set 12 | iberia
# Processing Record 12 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 13 of Set 12 | tondano
# Processing Record 14 of Set 12 | lofthus
# Processing Record 15 of Set 12 | khiri mat
# Processing Record 16 of Set 12 | tessalit
# Processing Record 17 of Set 12 | great falls
# Processing Record 18 of Set 12 | kortkeros
# Processing Record 19 of Set 12 | puri
# Processing Record 20 of Set 12 | uribia
# Processing Record 21 of Set 12 | cocal
# Processing Record 22 of Set 12 | batagay
# Processing Record 23 of Set 12 | winnemucca
# Processing Record 24 of Set 12 | ilulissat
# Processing Record 25 of Set 12 | kutum
# Processing Record 26 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 27 of Set 12 | andenes
# Processing Record 28 of Set 12 | bochil
# Processing Record 29 of Set 12 | tuatapere
# Processing Record 30 of Set 12 | araouane
# Processing Record 31 of Set 12 | santa marta
# Processing Record 32 of Set 12 | muravlenko
# Processing Record 33 of Set 12 | suluq
# Processing Record 34 of Set 12 | matara
# Processing Record 35 of Set 12 | gilroy
# Processing Record 36 of Set 12 | harboore
# Processing Record 37 of Set 12 | sadiqabad
# Processing Record 38 of Set 12 | maimon
# City not found. Skipping...
# Processing Record 39 of Set 12 | great bend
# Processing Record 40 of Set 12 | zambezi
# Processing Record 41 of Set 12 | gizo
# Processing Record 42 of Set 12 | amga
# Processing Record 43 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 12 | sendafa
# Processing Record 45 of Set 12 | pijijiapan
# Processing Record 46 of Set 12 | imeni poliny osipenko
# Processing Record 47 of Set 12 | bridgend
# Processing Record 48 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 12 | la ronge
# Processing Record 50 of Set 12 | baruun-urt
# Processing Record 1 of Set 13 | roquetas de mar
# Processing Record 2 of Set 13 | dudinka
# Processing Record 3 of Set 13 | chernolesskoye
# Processing Record 4 of Set 13 | mutis
# Processing Record 5 of Set 13 | katy
# Processing Record 6 of Set 13 | bintulu
# Processing Record 7 of Set 13 | sakhon nakhon
# Processing Record 8 of Set 13 | alyangula
# Processing Record 9 of Set 13 | moranbah
# Processing Record 10 of Set 13 | oranjestad
# Processing Record 11 of Set 13 | wawa
# Processing Record 12 of Set 13 | cururupu
# Processing Record 13 of Set 13 | sidi qasim
# City not found. Skipping...
# Processing Record 14 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 13 | naliya
# Processing Record 16 of Set 13 | badaojiang
# City not found. Skipping...
# Processing Record 17 of Set 13 | mozarlandia
# Processing Record 18 of Set 13 | isakly
# Processing Record 19 of Set 13 | jangipur
# Processing Record 20 of Set 13 | sorland
# Processing Record 21 of Set 13 | kholtoson
# Processing Record 22 of Set 13 | parabel
# Processing Record 23 of Set 13 | agbor
# Processing Record 24 of Set 13 | lodwar
# Processing Record 25 of Set 13 | bilma
# Processing Record 26 of Set 13 | umm lajj
# Processing Record 27 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 13 | can tho
# Processing Record 29 of Set 13 | rosario oeste
# Processing Record 30 of Set 13 | adrar
# Processing Record 31 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 13 | darab
# Processing Record 33 of Set 13 | frascati
# Processing Record 34 of Set 13 | kpandu
# Processing Record 35 of Set 13 | haikou
# Processing Record 36 of Set 13 | sola
# Processing Record 37 of Set 13 | bloemfontein
# Processing Record 38 of Set 13 | curuguaty
# Processing Record 39 of Set 13 | ippy
# Processing Record 40 of Set 13 | longview
# Processing Record 41 of Set 13 | sept-iles
# Processing Record 42 of Set 13 | maceio
# Processing Record 43 of Set 13 | la peca
# Processing Record 44 of Set 13 | kondinskoye
# Processing Record 45 of Set 13 | moron
# Processing Record 46 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 47 of Set 13 | shenkursk
# Processing Record 48 of Set 13 | ostersund
# Processing Record 49 of Set 13 | anchorage
# Processing Record 50 of Set 13 | endwell
# Processing Record 1 of Set 14 | kamenka
# Processing Record 2 of Set 14 | villa guerrero
# Processing Record 3 of Set 14 | muroto
# Processing Record 4 of Set 14 | half moon bay
# Processing Record 5 of Set 14 | havoysund
# Processing Record 6 of Set 14 | mitu
# Processing Record 7 of Set 14 | hommelvik
# Processing Record 8 of Set 14 | itarema
# Processing Record 9 of Set 14 | ostrovnoy
# Processing Record 10 of Set 14 | miandoab
# Processing Record 11 of Set 14 | ulladulla
# Processing Record 12 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 14 | guhagar
# Processing Record 14 of Set 14 | chumikan
# Processing Record 15 of Set 14 | bagotville
# Processing Record 16 of Set 14 | san jose
# Processing Record 17 of Set 14 | nimes
# Processing Record 18 of Set 14 | maragogi
# Processing Record 19 of Set 14 | pucallpa
# Processing Record 20 of Set 14 | kodinsk
# Processing Record 21 of Set 14 | callaway
# Processing Record 22 of Set 14 | toora-khem
# Processing Record 23 of Set 14 | gravdal
# Processing Record 24 of Set 14 | damara
# Processing Record 25 of Set 14 | correntina
# Processing Record 26 of Set 14 | clarence town
# Processing Record 27 of Set 14 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 28 of Set 14 | carndonagh
# Processing Record 29 of Set 14 | altay
# Processing Record 30 of Set 14 | boshnyakovo
# Processing Record 31 of Set 14 | manokwari
# Processing Record 32 of Set 14 | addis zemen
# City not found. Skipping...
# Processing Record 33 of Set 14 | tebingtinggi
# Processing Record 34 of Set 14 | mbini
# Processing Record 35 of Set 14 | aksu
# Processing Record 36 of Set 14 | san juan
# Processing Record 37 of Set 14 | bareli
# Processing Record 38 of Set 14 | urumqi
# Processing Record 39 of Set 14 | sao felix do xingu
# Processing Record 40 of Set 14 | lishu
# Processing Record 41 of Set 14 | mayo
# Processing Record 42 of Set 14 | formosa do rio preto
# Processing Record 43 of Set 14 | okakarara
# Processing Record 44 of Set 14 | fort-shevchenko
# Processing Record 45 of Set 14 | port lincoln
# Processing Record 46 of Set 14 | grindavik
# Processing Record 47 of Set 14 | rypefjord
# Processing Record 48 of Set 14 | kangaba
# Processing Record 49 of Set 14 | valea chioarului
# Processing Record 50 of Set 14 | la asuncion
# Processing Record 1 of Set 15 | bandarbeyla
# Processing Record 2 of Set 15 | berdigestyakh
# Processing Record 3 of Set 15 | tubuala
# Processing Record 4 of Set 15 | totness
# Processing Record 5 of Set 15 | nicoya
# Processing Record 6 of Set 15 | ayagoz
# Processing Record 7 of Set 15 | zyryanka
# Processing Record 8 of Set 15 | bereda
# Processing Record 9 of Set 15 | casablanca
# Processing Record 10 of Set 15 | kormilovka
# Processing Record 11 of Set 15 | quelimane
# Processing Record 12 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 13 of Set 15 | onega
# Processing Record 14 of Set 15 | poronaysk
# Processing Record 15 of Set 15 | avera
# Processing Record 16 of Set 15 | davenda
# Processing Record 17 of Set 15 | cap malheureux
# Processing Record 18 of Set 15 | makokou
# Processing Record 19 of Set 15 | sisophon
# Processing Record 20 of Set 15 | edd
# Processing Record 21 of Set 15 | khani
# Processing Record 22 of Set 15 | dakar
# Processing Record 23 of Set 15 | taybad
# Processing Record 24 of Set 15 | talas
# Processing Record 25 of Set 15 | oriximina
# Processing Record 26 of Set 15 | venice
# Processing Record 27 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 15 | atoka
# Processing Record 29 of Set 15 | la vista
# Processing Record 30 of Set 15 | svetlyy
# Processing Record 31 of Set 15 | matay
# Processing Record 32 of Set 15 | tecoanapa
# Processing Record 33 of Set 15 | sawtell
# Processing Record 34 of Set 15 | labuan
# Processing Record 35 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 15 | sheffield
# Processing Record 37 of Set 15 | jishou
# Processing Record 38 of Set 15 | loksa
# Processing Record 39 of Set 15 | saint anthony
# Processing Record 40 of Set 15 | kupang
# Processing Record 41 of Set 15 | bani
# Processing Record 42 of Set 15 | agua prieta
# Processing Record 43 of Set 15 | ola
# Processing Record 44 of Set 15 | along
# Processing Record 45 of Set 15 | pilas
# Processing Record 46 of Set 15 | mhango
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Karwar  14.8000   74.1333     78.35        86          43       16.53
# 1       Namibe -15.1961   12.1522     61.38        90          54        8.57
# 2  Tuktoyaktuk  69.4541 -133.0374     53.60        82          75       14.97
# 3      Rikitea -23.1203 -134.9692     73.15        70          77       20.94
# 4        Vaini -21.2000 -175.2000     75.36        83          40       12.66
# 5     Khatanga  71.9667  102.5000     44.62        71         100        7.02
# 6      Ushuaia -54.8000  -68.3000     37.06        87          40        3.44
# 7   Chokurdakh  70.6333  147.9167     49.66        71         100        9.86
# 8     Acapulco  16.8634  -99.8901     87.62        62          75        8.05
# 9  New Norfolk -42.7826  147.0587     41.90        84          98        1.74
#
#   Country                 Date Current Description
# 0      IN  2022-08-11 21:38:44    scattered clouds
# 1      AO  2022-08-11 21:38:45       broken clouds
# 2      CA  2022-08-11 21:38:46       broken clouds
# 3      PF  2022-08-11 21:38:46       broken clouds
# 4      TO  2022-08-11 21:38:47    scattered clouds
# 5      RU  2022-08-11 21:38:47          light rain
# 6      AR  2022-08-11 21:34:36    scattered clouds
# 7      RU  2022-08-11 21:38:48     overcast clouds
# 8      MX  2022-08-11 21:38:49       broken clouds
# 9      AU  2022-08-11 21:38:50     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Karwar      IN  14.8000   74.1333     78.35        86          43
# 1       Namibe      AO -15.1961   12.1522     61.38        90          54
# 2  Tuktoyaktuk      CA  69.4541 -133.0374     53.60        82          75
# 3      Rikitea      PF -23.1203 -134.9692     73.15        70          77
# 4        Vaini      TO -21.2000 -175.2000     75.36        83          40
# 5     Khatanga      RU  71.9667  102.5000     44.62        71         100
# 6      Ushuaia      AR -54.8000  -68.3000     37.06        87          40
# 7   Chokurdakh      RU  70.6333  147.9167     49.66        71         100
# 8     Acapulco      MX  16.8634  -99.8901     87.62        62          75
# 9  New Norfolk      AU -42.7826  147.0587     41.90        84          98
#
#    Wind Speed Current Description
# 0       16.53    scattered clouds
# 1        8.57       broken clouds
# 2       14.97       broken clouds
# 3       20.94       broken clouds
# 4       12.66    scattered clouds
# 5        7.02          light rain
# 6        3.44    scattered clouds
# 7        9.86     overcast clouds
# 8        8.05       broken clouds
# 9        1.74     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
import os
os.getcwd()
# Out:
# '/Users/lalohuerta/Desktop/BOOTCAMP_DATA_ANALYTICS /MODULE 6 /World_Weather_Analysis/Weather_Database'

# %%
for subdir, dirs, files in os.walk('./'):
    for file in files:
      print(file)
# Out:
# Weather_Database.ipynb
# .DS_Store
# config.py
# WeatherPy_Database.csv
# config.cpython-37.pyc
# Weather_Database-checkpoint.ipynb
